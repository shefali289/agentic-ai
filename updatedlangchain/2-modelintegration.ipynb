# %% [markdown]
# ### Models Integration with OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ## OpenAI Model Integration

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")
# model

# Invoke the OpenAI model
response = model.invoke("Hello, how are you?")
print(response.text)

# %%
### ChatOpenAI - alternative to chat initialization using init_chat_model for OpenAI models
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4.1")
response = model.invoke("Hello, how are you?")
print(response.text)

# %% [markdown]
# ## Google Gemini Model Integration

# %%
# Google Gemini Model Integration
model = init_chat_model("google_genai:gemini-flash-lite-latest")

response = model.invoke("Hello, how are you?")
print(response.text)
# Out:
# Hello! I'm doing well, thank you for asking. How can I help you today?

# %%
### ChatGoogleGenerativeAI - alternative to chat initialization using init_chat_model for Google models
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-flash-lite-latest")
response = model.invoke("Hello, how are you?")
print(response.text)
# Out:
# Hello! I'm doing well, thank you for asking. How can I help you today?

# %% [markdown]
# ## GROQ Model Integration

# %%
# GROQ Model Integration
model = init_chat_model("groq:openai/gpt-oss-120b")

response = model.invoke("Hello, how are you?")
print(response.text)

# %%
### ChatGroq - alternative to chat initialization using init_chat_model for GROQ models
from langchain_groq import ChatGroq
model = ChatGroq(model="openai/gpt-oss-120b")
response = model.invoke("Hello, how are you?")
print(response.text)
# Out:
# Hello! I'm doing great, thank you for asking. How can I assist you today?

# %% [markdown]
# ### Streaming and Batch
#
# ### Streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
# model.stream("Write me a 200 word paragraph in AI")

for chunk in model.stream("Write me a 200 word paragraph in AI"):
    print(chunk.text, end="|", flush=True)
# Out:
# Artificial| intelligence represents a profound paradigm shift in human capability, operating as a catalyst for unprecedented| technological evolution. By harnessing massive datasets, sophisticated neural networks, and relentless computational power, modern algorithms can now simulate cognitive functions that| were once the exclusive domain of biological entities. Machine learning models discern complex patterns, predict future trends, and generate novel content with a fluency| that blurs the boundary between human and machine creativity. From optimizing global supply chains and accelerating pharmaceutical drug discovery to diagnosing anomalies| in medical imaging, AI transcends mere automation; it acts as a synthetic collaborator, augmenting human intelligence and problem-solving.| However, this ascent introduces significant ethical and societal responsibilities. As autonomous systems become deeply integrated into critical infrastructure, finance, and| governance, ensuring transparency, fairness, and robust security is paramount. We must rigorously govern algorithmic bias and data privacy to prevent| systemic inequalities. Ultimately, artificial intelligence is not merely a tool for economic disruption, but a mirror reflecting our own intellectual ambitions|. Its true measure will not be found in its computational speed, but in how effectively it empowers humanity to construct a more sustainable, equitable,| and enlightened future.|||

# %% [markdown]
# ### Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What causes rainbows?"
])

for response in responses:
    print(response.text)

# %%
model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What causes rainbows?"
],
config={
    "max_concurrency": 5 # Limit the number of parallel calls to 5
    } 
)
